# %% [markdown]
# # Problem Description
# The goal is to hire the best intern from the given dataset. The dataset consists of 14 columns, and we need to evaluate the interns based on their scores in various categories and select the intern with the highest aggregate score.
#
# ## Approach
# The approach is to assign aggregates to different categories or features and calculate the aggregate score for each intern. The total aggregate score for all categories should sum up to 10.
#
# The relevant columns considered for evaluation are:
#
# - **Python** (Aggregate: 1.5)
# - **Machine Learning** (Aggregate: 1.8)
# - **Deep Learning** (Aggregate: 1.8)
# - **Natural Language Processing (NLP)** (Aggregate: 1.5)
# - **Other Skills** (Aggregate: 0.5)
# - **Availability** (Aggregate: 0.5)
# - **Degree** (Aggregate: 0.5)
# - **Stream** (Aggregate: 1.4)
# - **Year of Graduation** (Aggregate: 0.5)
# - **Study** (Aggregate: 1)
#
# The challenge in the dataset is handling missing values in the **Degree** and **Stream** columns. To address this:
#
# - For the **Degree** column, replace the missing values with "Unknown" to retain valuable data for evaluation.
# - For the **Stream** column, replace the missing values with "Unknown" to retain valuable data for evaluation.
#
# ### Assigning weights, Values to each column in the dataset(specific values will be assigned based on the relevance to data science and data analytics internships):
# - **Python**, **Machine Learning**, **Deep Learning**, and **Natural Language Processing (NLP)** columns are left as they are, on a scale of 0 to 3.
#
# - For each extra skill mentioned in the **Other Skills** column, a value of 0.03 is assigned.
#
# - For **Study Aggregate**:
#   - For 10th grade, a value of 0.05 is assigned.
#   - For 12th grade, a value of 0.1 is assigned.
#   - For UG, a value of 0.3 is assigned.
#   - For PG, a value of 0.05 is assigned.
#   - The total value being 0.5, the associated weight should be 2 so that the aggregate is 1.
#
#
# - For **Stream Aggregate**:
#     - As studying in a relevant stream is important a aggregate of 1.4 is chosen.
#     - stream is given prioroty based on AI /ML /DS  > CSE > IT,IOT > ECE, Mechanical > Metallurgy, Pharmacy
#     - based on keywords value and weight are chosen so that the total aggregate is 1.4
#
# - For ** Degree Aggregate**:
#     - Degree is given prioroty based on Masters > Bachelor's
#     - based on keywords value and weight are chosen so that the aggregate is 0.5
#
#
# - For **Python Aggregate**:
#     - values were choosen directly from given data set (in scale of 0 to 3)
#     - weight associated is 0.5
#     - Total Aggregate is 1.5
#
# - For **Machine Learning Aggregate**:
#     - values were choosen directly from given data set (in scale of 0 to 3)
#     - weight associated is 0.5
#     - Total Aggregate is 1.8
#
# - For **NLP Aggregate**:
#     - values were choosen directly from given data set (in scale of 0 to 3)
#     - weight associated is 0.5
#     - Total Aggregate is 1.5
#
# - For **Deep Learning Aggreagate**:
#     - values were choosen directly from given data set (in scale of 0 to 3)
#     - weight associated is 0.5
#     - Total Aggregate is 1.8
#
# - For **Availability Aggregate**:
#     - if the canditate is available for 3 months internship , immediately as value of 1 is assigned
#     - weight associated is 0.5
#     - Total Aggregate is 0.5
#
# - For **Year of Graduation Aggregate**:
#     - 2024 graduates are more preferred,so value of 3 - (abs(2024) - Current Year of Graduation) which returns a value in scale of (0-3)
#     - Thus weight of 0.166 is assigned
#     - Total Aggregates is 0.5
#
# - For **Other Skills Aggregate**:
#     - Each Extra skill is assigned a value of
#
# ## Scoring and Ranking Metrics
# - Assign aggregates to each feature/category based on its importance and relevance to the hiring decision.
# - Calculate the score for each intern by multiplying the feature values with their respective aggregates and summing them up.
# - Rank the interns based on their aggregate scores.
# - Select the intern with the highest aggregate score as the best candidate for hiring.
#
# By following this approach, we can effectively evaluate the interns and identify the best candidate for the internship opportunity.
#
# Please note that these aggregates and weights are adjustable and subjective based on the specific requirements and preferences of the evaluation criteria. Feel free to further customize them as per your specific needs.

# %%
# importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Preparation:

# %%
# Reading CSV File
df = pd.read_csv('/home/itachi/Documents/data.csv')
df
# Out:
#       Name  Python (out of 3)  Machine Learning (out of 3)  \
# 0      NaN                  1                            0
# 1      NaN                  2                            0
# 2      NaN                  2                            2
# 3      NaN                  3                            2
# 4      NaN                  2                            2
# ...    ...                ...                          ...
# 1131   NaN                  2                            2
# 1132   NaN                  3                            3
# 1133   NaN                  3                            1
# 1134   NaN                  2                            1
# 1135   NaN                  2                            0
#
#       Natural Language Processing (NLP) (out of 3)  Deep Learning (out of 3)  \
# 0                                                0                         1
# 1                                                0                         0
# 2                                                0                         0
# 3                                                2                         0
# 4                                                0                         0
# ...                                            ...                       ...
# 1131                                             0                         2
# 1132                                             2                         3
# 1133                                             3                         3
# 1134                                             0                         0
# 1135                                             0                         0
#
#                                            Other skills  \
# 0     MS-Excel, MS-Word, Deep Learning, MySQL, Pytho...
# 1     Git, GitHub, Linux, Adobe After Effects, Adobe...
# 2     Amazon Web Services (AWS), Docker, Hadoop, MS-...
# 3     Adobe XD, BIG DATA ANALYTICS, Canva, Data Anal...
# 4     C++ Programming, Data Science, Machine Learnin...
# ...                                                 ...
# 1131  Data Analytics, Amazon Web Services (AWS), Dat...
# 1132  Deep Learning, Docker, HTML, MS-Office, Machin...
# 1133  Data Science, Deep Learning, English Proficien...
# 1134  Python, Data Analytics, MS-Excel, Machine Lear...
# 1135  C++ Programming, Database Management System (D...
#
#      Are you available for 3 months, starting immediately, for a full-time work from home internship?   \
# 0     Yes, I am available for 3 months starting imme...
# 1     Yes, I am available for 3 months starting imme...
# 2     Yes, I am available for 3 months starting imme...
# 3     Yes, I am available for 3 months starting imme...
# 4     Yes, I am available for 3 months starting imme...
# ...                                                 ...
# 1131  Yes, I am available for 3 months starting imme...
# 1132  Yes, I am available for 3 months starting imme...
# 1133  Yes, I am available for 3 months starting imme...
# 1134  Yes, I am available for 3 months starting imme...
# 1135  Yes, I am available for 3 months starting imme...
#
#                              Degree                          Stream  \
# 0     Bachelor of Vocation (B.Voc.)            Software Engineering
# 1                            B.Tech  Computer Science & Engineering
# 2          Master of Science (M.S.)      Data Science And Analytics
# 3     Bachelor of Engineering (B.E)                             NaN
# 4                            B.Tech                Computer Science
# ...                             ...                             ...
# 1131                         B.Tech          Mechanical Engineering
# 1132                         B.Tech  Computer Science & Engineering
# 1133                         B.Tech   Electronics and Communication
# 1134                         B.Tech                Computer Science
# 1135                         B.Tech                     Engineering
#
#       Current Year Of Graduation Performance_PG Performance_UG Performance_12  \
# 0                           2021            NaN         6.50/7            NaN
# 1                           2024            NaN        8.90/10            NaN
# 2                           2022            NaN            NaN            NaN
# 3                           2024            NaN            NaN    85.60/85.60
# 4                           2023            NaN        8.10/10    93.40/93.40
# ...                          ...            ...            ...            ...
# 1131                        2021            NaN            NaN            NaN
# 1132                        2024            NaN            NaN            NaN
# 1133                        2025            NaN        8.77/10      9.40/9.40
# 1134                        2024            NaN        7.90/10    90.00/90.00
# 1135                        2024            NaN            NaN            NaN
#
#      Performance_10
# 0               NaN
# 1               NaN
# 2               NaN
# 3       10.00/10.00
# 4       10.00/10.00
# ...             ...
# 1131            NaN
# 1132            NaN
# 1133            NaN
# 1134            NaN
# 1135            NaN
#
# [1136 rows x 14 columns]

# %%
# Checking for data types of items present in each column
result = df.dtypes
print(result)
# Out:
# Name                                                                                                 float64
# Python (out of 3)                                                                                      int64
# Machine Learning (out of 3)                                                                            int64
# Natural Language Processing (NLP) (out of 3)                                                           int64
# Deep Learning (out of 3)                                                                               int64
# Other skills                                                                                          object
# Are you available for 3 months, starting immediately, for a full-time work from home internship?      object
# Degree                                                                                                object
# Stream                                                                                                object
# Current Year Of Graduation                                                                             int64
# Performance_PG                                                                                        object
# Performance_UG                                                                                        object
# Performance_12                                                                                        object
# Performance_10                                                                                        object
# dtype: object

# %%
# checking how many null values are being persent in each coluumn
df.isnull().sum()
# Out:
# Name                                                                                                 1136
# Python (out of 3)                                                                                       0
# Machine Learning (out of 3)                                                                             0
# Natural Language Processing (NLP) (out of 3)                                                            0
# Deep Learning (out of 3)                                                                                0
# Other skills                                                                                           66
# Are you available for 3 months, starting immediately, for a full-time work from home internship?        0
# Degree                                                                                                 43
# Stream                                                                                                170
# Current Year Of Graduation                                                                              0
# Performance_PG                                                                                        952
# Performance_UG                                                                                        654
# Performance_12                                                                                        643
# Performance_10                                                                                        709
# dtype: int64

# %%
# Filling Nan values with key words
df['Degree'].fillna('Unknown', inplace = True)
df['Stream'].fillna('Unknown', inplace = True)
df['Other skills'].fillna('No additional skill' , inplace = True)
df['Performance_10'].fillna('0/0',inplace = True)
df['Performance_12'].fillna('0/0',inplace = True)
df['Performance_PG'].fillna('0/0', inplace = True)
df['Performance_UG'].fillna('0/0', inplace = True)
df.isnull().sum()
# Out:
# Name                                                                                                 1136
# Python (out of 3)                                                                                       0
# Machine Learning (out of 3)                                                                             0
# Natural Language Processing (NLP) (out of 3)                                                            0
# Deep Learning (out of 3)                                                                                0
# Other skills                                                                                            0
# Are you available for 3 months, starting immediately, for a full-time work from home internship?        0
# Degree                                                                                                  0
# Stream                                                                                                  0
# Current Year Of Graduation                                                                              0
# Performance_PG                                                                                          0
# Performance_UG                                                                                          0
# Performance_12                                                                                          0
# Performance_10                                                                                          0
# dtype: int64

# %%
# data frame after filling null values 
df.head(5)
# Out:
#    Name  Python (out of 3)  Machine Learning (out of 3)  \
# 0   NaN                  1                            0
# 1   NaN                  2                            0
# 2   NaN                  2                            2
# 3   NaN                  3                            2
# 4   NaN                  2                            2
#
#    Natural Language Processing (NLP) (out of 3)  Deep Learning (out of 3)  \
# 0                                             0                         1
# 1                                             0                         0
# 2                                             0                         0
# 3                                             2                         0
# 4                                             0                         0
#
#                                         Other skills  \
# 0  MS-Excel, MS-Word, Deep Learning, MySQL, Pytho...
# 1  Git, GitHub, Linux, Adobe After Effects, Adobe...
# 2  Amazon Web Services (AWS), Docker, Hadoop, MS-...
# 3  Adobe XD, BIG DATA ANALYTICS, Canva, Data Anal...
# 4  C++ Programming, Data Science, Machine Learnin...
#
#   Are you available for 3 months, starting immediately, for a full-time work from home internship?   \
# 0  Yes, I am available for 3 months starting imme...
# 1  Yes, I am available for 3 months starting imme...
# 2  Yes, I am available for 3 months starting imme...
# 3  Yes, I am available for 3 months starting imme...
# 4  Yes, I am available for 3 months starting imme...
#
#                           Degree                          Stream  \
# 0  Bachelor of Vocation (B.Voc.)            Software Engineering
# 1                         B.Tech  Computer Science & Engineering
# 2       Master of Science (M.S.)      Data Science And Analytics
# 3  Bachelor of Engineering (B.E)                         Unknown
# 4                         B.Tech                Computer Science
#
#    Current Year Of Graduation Performance_PG Performance_UG Performance_12  \
# 0                        2021            0/0         6.50/7            0/0
# 1                        2024            0/0        8.90/10            0/0
# 2                        2022            0/0            0/0            0/0
# 3                        2024            0/0            0/0    85.60/85.60
# 4                        2023            0/0        8.10/10    93.40/93.40
#
#   Performance_10
# 0            0/0
# 1            0/0
# 2            0/0
# 3    10.00/10.00
# 4    10.00/10.00

# %%
# Converting Other skills to a numbered scale
ans = 1
for item in df['Other skills']:
    ans = max(len(item.split(',')),ans)
df['Other skills_Aggregate'] = df['Other skills'].apply(lambda x: (1/ans)*len(x.split(',')))

# %%
# data frame after scaling otherskills to value
df.head(5)
# Out:
#    Name  Python (out of 3)  Machine Learning (out of 3)  \
# 0   NaN                  1                            0
# 1   NaN                  2                            0
# 2   NaN                  2                            2
# 3   NaN                  3                            2
# 4   NaN                  2                            2
#
#    Natural Language Processing (NLP) (out of 3)  Deep Learning (out of 3)  \
# 0                                             0                         1
# 1                                             0                         0
# 2                                             0                         0
# 3                                             2                         0
# 4                                             0                         0
#
#                                         Other skills  \
# 0  MS-Excel, MS-Word, Deep Learning, MySQL, Pytho...
# 1  Git, GitHub, Linux, Adobe After Effects, Adobe...
# 2  Amazon Web Services (AWS), Docker, Hadoop, MS-...
# 3  Adobe XD, BIG DATA ANALYTICS, Canva, Data Anal...
# 4  C++ Programming, Data Science, Machine Learnin...
#
#   Are you available for 3 months, starting immediately, for a full-time work from home internship?   \
# 0  Yes, I am available for 3 months starting imme...
# 1  Yes, I am available for 3 months starting imme...
# 2  Yes, I am available for 3 months starting imme...
# 3  Yes, I am available for 3 months starting imme...
# 4  Yes, I am available for 3 months starting imme...
#
#                           Degree                          Stream  \
# 0  Bachelor of Vocation (B.Voc.)            Software Engineering
# 1                         B.Tech  Computer Science & Engineering
# 2       Master of Science (M.S.)      Data Science And Analytics
# 3  Bachelor of Engineering (B.E)                         Unknown
# 4                         B.Tech                Computer Science
#
#    Current Year Of Graduation Performance_PG Performance_UG Performance_12  \
# 0                        2021            0/0         6.50/7            0/0
# 1                        2024            0/0        8.90/10            0/0
# 2                        2022            0/0            0/0            0/0
# 3                        2024            0/0            0/0    85.60/85.60
# 4                        2023            0/0        8.10/10    93.40/93.40
#
#   Performance_10  Other skills_Aggregate
# 0            0/0                0.095238
# 1            0/0                0.523810
# 2            0/0                0.126984
# 3    10.00/10.00                0.285714
# 4    10.00/10.00                0.063492

# %%
print("--------------- UNIQUE VALUES IN DEGREE COLUMN ------------------")
s = set(df['Degree'].values)
for item in s:
    print(item)
print("NUMBER OF UNIQUE DEGREE'S :",len(s))
# Out:
# --------------- UNIQUE VALUES IN DEGREE COLUMN ------------------
# Bachelor of Computer Applications (BCA) (Hons.)
# Integrated B.E & MBA
# Post Graduate Diploma In Data Analytics And Machine Learning
# DIPLOMA IN CIVIL Engineering
# Master of Engineering (M.E)
# Bachelor of Artificial Intelligence
# M.Sc. in Data Science
# Msc.Data Analytics
# Integrated M.Sc.
# Bachelor of Commerce (B.Com)
# Integrated B.Tech & M.Sc
# M.Sc (Information Technology)
# Bachelor of Chemical Engineering
# B.sc(chem)
# B.A
# Post Graduate Programme (PGP)
# Integrated B.E & M.Sc
# PG Diploma in Data Science
# Business Engineering (BE)
# B.E Computer Science and Engineering (Artificial Intelligence and machine Learning)
# BE
# Master of Information Technology (M.I.T.)
# Master of Science (M.Sc) (Tech)
# Bachelor Of Technology (B.Tech) CS
# Bachelor of Arts (B.A.)
# Post Graduate Diploma in Management (P.G.D.M.)
# Bachelor of Computer Engineering
# Integrated MCA
# B.Tech
# Post Graduate Diploma in Human Resource Management (P.G.D.H.R.M.)
# Diploma In Pharmacy
# Hsc
# Btech
# Bachelors Of Software Engineering
# B.Tech (Hons.)
# Master of Computer Applications (MCA)
# Bachelor of Engineering (B.E) (Hons.)
# Integrated B.Tech
# ITI Electrical Engineering
# B.Tech(CSE)
# Bachelor of Computer Science (B.C.S.)
# Master Of Science
# Ms In Data Science
# Bachelor Of Mechanical Engineering
# Bachelor of Technology (B.Tech)
# Master in Artificial intelligence
# Master of Computer Science (M.C.S.)
# Unknown
# Bachelors Of Science
# Bachelors of Data Science
# Graduate Certificate Program
# M.Sc
# Master of Science (M.S.)
# Master of Arts (M.A.)
# Post Graduate Diploma
# Master of Data Science
# M.Sc. Management
# Bsc
# Master of Technology (M.Tech)
# Bachelor Of Science (B.Sc), Data Science
# Integrated B.Tech & M.Tech
# Master of Science (M.Sc)
# Advanced Certification In Data Science
# Bachelor of Business Administration (B.B.A.)
# Post Graduation Diploma
# B.Sc
# M.Tech
# Certified Data Scientist
# Bachelor of Science (B.Sc)
# Bachelor of Information Technology (B.I.T.)
# Bachelor of Science (B.Sc) (Hons.)
# B.tech Artificial Intelligence And Data Science
# Bachelor of Science (B.Sc) (Pass)
# Bachelor of Vocation (B.Voc.)
# Bachelor of Engineering (B.E)
# BS in Data Science and Applications
# Automobile Engineering
# B.Tech (CSE) with specialization in Cyber Security
# Bachelor of Commerce (B.Com) (Hons.)
# Dual Degree
# Post Graduate Diploma in Big Data Analytics (PG-DBDA)
# Executive PG Program (EPGP)
# Integrated B.E & M.Tech
# B.Ed Special Education
# Integrated M.Tech
# MCA
# Bachelor of Computer Applications (BCA)
# Bachelor Of Engineering
# High School Student. I Want An Internship
# MBA
# Post Graduate Diploma In Computer Applications (P.G.D.C.A.)
# PGP
# NUMBER OF UNIQUE DEGREE'S : 92

# %%
keywords_1 = ['bachelor','b.tech','btech']
keywords_2 = ['master', 'm.tech','mtech']
keywords_3 = ['phd','Ph.d']
keywords_4 = ['ds','artificial','ai','data','computer','statistics']
keywords_5 = ['missing','unknown']

List = []
for item in df['Degree']:
    list = item.split(' ')
    value = 0.1 
    for keyword in list:
        if keyword.lower() in keywords_1:
            value += 0.1
        elif keyword.lower() in keywords_2:
            value += 0.2
        elif keyword.lower() in keywords_3:
            value += 0.3
        elif keyword.lower() in keywords_4:
            value += 0.1
        elif keyword.lower() in keywords_5:
            value -= 0.1
    List.append(value)
df['Degree_value'] = List
df.head(5)
# Out:
#    Name  Python (out of 3)  Machine Learning (out of 3)  \
# 0   NaN                  1                            0
# 1   NaN                  2                            0
# 2   NaN                  2                            2
# 3   NaN                  3                            2
# 4   NaN                  2                            2
#
#    Natural Language Processing (NLP) (out of 3)  Deep Learning (out of 3)  \
# 0                                             0                         1
# 1                                             0                         0
# 2                                             0                         0
# 3                                             2                         0
# 4                                             0                         0
#
#                                         Other skills  \
# 0  MS-Excel, MS-Word, Deep Learning, MySQL, Pytho...
# 1  Git, GitHub, Linux, Adobe After Effects, Adobe...
# 2  Amazon Web Services (AWS), Docker, Hadoop, MS-...
# 3  Adobe XD, BIG DATA ANALYTICS, Canva, Data Anal...
# 4  C++ Programming, Data Science, Machine Learnin...
#
#   Are you available for 3 months, starting immediately, for a full-time work from home internship?   \
# 0  Yes, I am available for 3 months starting imme...
# 1  Yes, I am available for 3 months starting imme...
# 2  Yes, I am available for 3 months starting imme...
# 3  Yes, I am available for 3 months starting imme...
# 4  Yes, I am available for 3 months starting imme...
#
#                           Degree                          Stream  \
# 0  Bachelor of Vocation (B.Voc.)            Software Engineering
# 1                         B.Tech  Computer Science & Engineering
# 2       Master of Science (M.S.)      Data Science And Analytics
# 3  Bachelor of Engineering (B.E)                         Unknown
# 4                         B.Tech                Computer Science
#
#    Current Year Of Graduation Performance_PG Performance_UG Performance_12  \
# 0                        2021            0/0         6.50/7            0/0
# 1                        2024            0/0        8.90/10            0/0
# 2                        2022            0/0            0/0            0/0
# 3                        2024            0/0            0/0    85.60/85.60
# 4                        2023            0/0        8.10/10    93.40/93.40
#
#   Performance_10  Other skills_Aggregate  Degree_value
# 0            0/0                0.095238           0.2
# 1            0/0                0.523810           0.2
# 2            0/0                0.126984           0.3
# 3    10.00/10.00                0.285714           0.2
# 4    10.00/10.00                0.063492           0.2

# %%
print("--------------- UNIQUE VALUES IN STREAM COLUMN ------------------")
s = set(df['Stream'].values)
for item in s:
    print(item)
print("NUMBER OF UNIQUE STREAMS: " ,len(s))
# Out:
# --------------- UNIQUE VALUES IN STREAM COLUMN ------------------
# Machine Learning
# Post Graduate Diploma In Big Data Analytics
# Information science and engineering
# Agriculture Management
# Cs(aiml)
# Food Technology
# AI & DATA SCIENCE
# Computer  Science  And Engineering
# Microbiology
# Analytics And Big Data
# Commerce
# Minor Specialization In AI & ML (Hons.)
# Engineering
# computer science
# Finance
# Chemical Engineering
# Computer Science & Information Technology
# Engineering Physics
# Computer Science With Specialization In AI And ML
# Software Development
# Artificial Intellience & Data Science
# Artificial Intelligence And Data Science
# Computer Application(Data Science)
# Data Analytics
# Computer Science & Technology
# Computer Science & Engineering ( Machine Learning)
# Computer  Science And Engineering
# B.E. Computer
# Chemistry
# Nanotechnology
# Computational Data Science
# Data Science And Engineering
# Computer Science And Engineering (Data Science)
# Mathemtaics With Computer Science
# Computer Science And Technology
# Metallurgical And Materials Engineering
# Information and Communication Technology
# Computer Science (AI &ML)
# Computer And Communication Engineering
# communication engineering
# Electronics and Instrumentation
# Statistics
# CSE AI&ML
# Data Science And AI
# All Stream
# Data Science
# Artificial Intelligence, Machine Learning And Robotics
# Business Analytics
# financial economics
# Organic Chemistry
# Signal Processing Machine Learning
# Artificial Intelligence And Machine Learning (cse)
# International Business
# Data Science And Big Data Analytics
# Instrumentation and Control Engineering
# COMPUTER
# Electrical
# Agricultural Science
# Marketing
# Economics
# Computer Science And Engineering(data Science)
# Industrial Management
# Information Technology (Data Science)
# Computer Science & Engineering(Artificial Intelligence)
# Electronics and Telecommunication
# Business Development
# Information Science
# AIDS
# Ai&Ml
# Mathematics, Economics Minor
# Agriculture & Food Engineering
# Applied Mathematics
# CSE AIML
# Python,sql
# Electronics and Communication
# Climate Science And Technology
# Mechatronics
# Electrical and Electronics Engineering
# Computer Science & Engineering, Specializing In Ai & ML
# Data Science And Analytics
# AI
# Biochemical Engineering
# Computer Science(Artificial Intelligence And Machine Learning)
# Information Technology
# BUSINESS ANALYST
# Data Science And Statistics
# Aeronautical Engineering
# Unknown
# Computer Science & Engineering In Specialisation With Ai And Robotics
# Computer Science & Engineering In AIML
# AI/DA
# Computer Applications
# AIML
# Data Science With Business And Management
# IT
# Computer Science And IT
# Artificial Intelligence
# Mechanical
# Statistics With Data Science
# Biological Science
# Mathematics and Computing
# Computer  Science (Cloud Computing And AI In Association With IBM)
# Software Engineering
# Networks And Communication
# Mineral And Metallurgical Engg.
# Analytics And Finance
# AI & Ml
# Artificial Intelligence And Machine Learning
# Mining Engineering
# Leather Technology
# Electronics Engineering
# Computer Science & Engineering Data Science AI ML
# Botany
# Artificial Intelligence & Internet Of Things
# Computer Engineering In Artificial Intelligence
# cs
# Geography
# Advanced Computer Science
# CSE( Artificial Intelligence And Machine Learning )
# Automobile
# Artificial Intelligence And MachineLearning
# Metallurgical And Materials Science
# AI And Datascience
# Computer Science & Engineering(artificial Intelligence And Machine Learning)
# Computer Science And Engineering( Data Science)
# Data Science And Business Analytics
# Statistics Computing( DATA Science )
# Electronic Science
# CSE Hons DS&AI
# Computer Science & Engineering - AI & ML
# Computer Application
# Artificial Intelligence And Data Sciences
# Mathematics & Mechanical Engineering
# Arts
# Telecommunication Engineering
# Statistics And Analytics
# Computer Sciene And Engineering
# Mathematics
# Machine Learning ,NLP And Deep Learning
# Operations
# Metallurgical & Materials Engineering
# electronics
# INFORMATION TECHONOLGY
# Structural Engineering
# Programming And Data Science
# Commerce With Maths
# Computer Technology
# Computational Mechanics
# MlAI
# Polymer Science & Technology
# And Big Data Analytics
# Digital Systems And Computer Electronics
# Computational Science
# DIPLOMA IN COMPUTER APPLICATION
# Physics
# Artificial Intelligence & Machine Learning
# Civil Engineering
# Accounts
# Analytics
# Biomedical Engineering
# Computer Science & Engineering
# Computer & Communication Engineering
# Certification  IN AI AND ML
# Computer Science
# MCA
# Artificial Intelligence & Data Science
# Data Science Engineering
# Computer Science And Information Technology
# Data Science And Machine Learning
# Computer Science & Engineering (AI & ML)
# Electronics And Communication Engineering (ETE)
# Cse(Artificial Intelligence And Machine Learning)
# Electronics and Telecommunication Engineering (ETE)
# Information Technology (IT)
# Computer Sciences &Engineering
# Datascience
# IT(Data Science)
# Science
# Computer Scienece With Specialization In Cybersecurity And Data
# Compuer Science And Information Technology
# Electrical Engineering
# Mechanical Engineering
# Artificial Intelligence And Data Science Engineering
# Data Science And Business Analysis
# Bioengineering
# Computer Science With Specialization In Data Science
# E&TC
# NUMBER OF UNIQUE STREAMS:  187

# %%
# Assigning values to Stream
keywords_1 = ['ece','mechanical','electronics','physics','pharmacy','mineral','metallurgy','economics']
keywords_2 = ['iot','it','software','statistics']
keywords_3 = ['ds','artificial','ai','data','computer','ml']
keywords_5 = ['unknown','missing']
 
List = []
for item in df['Stream']:
    list = item.split(' ')
    value = 0.0 
    for keyword in list:
        if keyword.lower() in keywords_1:
            value += 0.3
        elif keyword.lower() in keywords_2:
            value += 0.4
        elif keyword.lower() in keywords_3:
            value += 0.7
        elif keyword.lower() in keywords_5:
            value -= 0.05
    if value > 0.7:
        value = 0.7
    List.append(value)
df['Stream_value'] = List
df.head(5)
# Out:
#    Name  Python (out of 3)  Machine Learning (out of 3)  \
# 0   NaN                  1                            0
# 1   NaN                  2                            0
# 2   NaN                  2                            2
# 3   NaN                  3                            2
# 4   NaN                  2                            2
#
#    Natural Language Processing (NLP) (out of 3)  Deep Learning (out of 3)  \
# 0                                             0                         1
# 1                                             0                         0
# 2                                             0                         0
# 3                                             2                         0
# 4                                             0                         0
#
#                                         Other skills  \
# 0  MS-Excel, MS-Word, Deep Learning, MySQL, Pytho...
# 1  Git, GitHub, Linux, Adobe After Effects, Adobe...
# 2  Amazon Web Services (AWS), Docker, Hadoop, MS-...
# 3  Adobe XD, BIG DATA ANALYTICS, Canva, Data Anal...
# 4  C++ Programming, Data Science, Machine Learnin...
#
#   Are you available for 3 months, starting immediately, for a full-time work from home internship?   \
# 0  Yes, I am available for 3 months starting imme...
# 1  Yes, I am available for 3 months starting imme...
# 2  Yes, I am available for 3 months starting imme...
# 3  Yes, I am available for 3 months starting imme...
# 4  Yes, I am available for 3 months starting imme...
#
#                           Degree                          Stream  \
# 0  Bachelor of Vocation (B.Voc.)            Software Engineering
# 1                         B.Tech  Computer Science & Engineering
# 2       Master of Science (M.S.)      Data Science And Analytics
# 3  Bachelor of Engineering (B.E)                         Unknown
# 4                         B.Tech                Computer Science
#
#    Current Year Of Graduation Performance_PG Performance_UG Performance_12  \
# 0                        2021            0/0         6.50/7            0/0
# 1                        2024            0/0        8.90/10            0/0
# 2                        2022            0/0            0/0            0/0
# 3                        2024            0/0            0/0    85.60/85.60
# 4                        2023            0/0        8.10/10    93.40/93.40
#
#   Performance_10  Other skills_Aggregate  Degree_value  Stream_value
# 0            0/0                0.095238           0.2          0.40
# 1            0/0                0.523810           0.2          0.70
# 2            0/0                0.126984           0.3          0.70
# 3    10.00/10.00                0.285714           0.2         -0.05
# 4    10.00/10.00                0.063492           0.2          0.70

# %%
# Assiging a value of 0.5 with the candiate is available for joining , else 0
Li = []
for item in df['Are you available for 3 months, starting immediately, for a full-time work from home internship? ']:
    if 'yes' in item.lower().split(','):
        Li.append(1)
    else:
        Li.append(0)
df['Availability_value'] = Li
df.head(5)
# Out:
#    Name  Python (out of 3)  Machine Learning (out of 3)  \
# 0   NaN                  1                            0
# 1   NaN                  2                            0
# 2   NaN                  2                            2
# 3   NaN                  3                            2
# 4   NaN                  2                            2
#
#    Natural Language Processing (NLP) (out of 3)  Deep Learning (out of 3)  \
# 0                                             0                         1
# 1                                             0                         0
# 2                                             0                         0
# 3                                             2                         0
# 4                                             0                         0
#
#                                         Other skills  \
# 0  MS-Excel, MS-Word, Deep Learning, MySQL, Pytho...
# 1  Git, GitHub, Linux, Adobe After Effects, Adobe...
# 2  Amazon Web Services (AWS), Docker, Hadoop, MS-...
# 3  Adobe XD, BIG DATA ANALYTICS, Canva, Data Anal...
# 4  C++ Programming, Data Science, Machine Learnin...
#
#   Are you available for 3 months, starting immediately, for a full-time work from home internship?   \
# 0  Yes, I am available for 3 months starting imme...
# 1  Yes, I am available for 3 months starting imme...
# 2  Yes, I am available for 3 months starting imme...
# 3  Yes, I am available for 3 months starting imme...
# 4  Yes, I am available for 3 months starting imme...
#
#                           Degree                          Stream  \
# 0  Bachelor of Vocation (B.Voc.)            Software Engineering
# 1                         B.Tech  Computer Science & Engineering
# 2       Master of Science (M.S.)      Data Science And Analytics
# 3  Bachelor of Engineering (B.E)                         Unknown
# 4                         B.Tech                Computer Science
#
#    Current Year Of Graduation Performance_PG Performance_UG Performance_12  \
# 0                        2021            0/0         6.50/7            0/0
# 1                        2024            0/0        8.90/10            0/0
# 2                        2022            0/0            0/0            0/0
# 3                        2024            0/0            0/0    85.60/85.60
# 4                        2023            0/0        8.10/10    93.40/93.40
#
#   Performance_10  Other skills_Aggregate  Degree_value  Stream_value  \
# 0            0/0                0.095238           0.2          0.40
# 1            0/0                0.523810           0.2          0.70
# 2            0/0                0.126984           0.3          0.70
# 3    10.00/10.00                0.285714           0.2         -0.05
# 4    10.00/10.00                0.063492           0.2          0.70
#
#    Availability_value
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1

# %%
# Assiging values for year of graduation
List = []
# Giving more priorty to 2024 Graduates , and difference between current year of graduation is subracted from a scale of 3 to calculate year of graduation value
for item in df['Current Year Of Graduation']:
    List.append(3-(abs(int(item)-2024)))
df['Current Year Of Graduation_value'] = List
df.head(5)
# Out:
#    Name  Python (out of 3)  Machine Learning (out of 3)  \
# 0   NaN                  1                            0
# 1   NaN                  2                            0
# 2   NaN                  2                            2
# 3   NaN                  3                            2
# 4   NaN                  2                            2
#
#    Natural Language Processing (NLP) (out of 3)  Deep Learning (out of 3)  \
# 0                                             0                         1
# 1                                             0                         0
# 2                                             0                         0
# 3                                             2                         0
# 4                                             0                         0
#
#                                         Other skills  \
# 0  MS-Excel, MS-Word, Deep Learning, MySQL, Pytho...
# 1  Git, GitHub, Linux, Adobe After Effects, Adobe...
# 2  Amazon Web Services (AWS), Docker, Hadoop, MS-...
# 3  Adobe XD, BIG DATA ANALYTICS, Canva, Data Anal...
# 4  C++ Programming, Data Science, Machine Learnin...
#
#   Are you available for 3 months, starting immediately, for a full-time work from home internship?   \
# 0  Yes, I am available for 3 months starting imme...
# 1  Yes, I am available for 3 months starting imme...
# 2  Yes, I am available for 3 months starting imme...
# 3  Yes, I am available for 3 months starting imme...
# 4  Yes, I am available for 3 months starting imme...
#
#                           Degree                          Stream  \
# 0  Bachelor of Vocation (B.Voc.)            Software Engineering
# 1                         B.Tech  Computer Science & Engineering
# 2       Master of Science (M.S.)      Data Science And Analytics
# 3  Bachelor of Engineering (B.E)                         Unknown
# 4                         B.Tech                Computer Science
#
#    Current Year Of Graduation Performance_PG Performance_UG Performance_12  \
# 0                        2021            0/0         6.50/7            0/0
# 1                        2024            0/0        8.90/10            0/0
# 2                        2022            0/0            0/0            0/0
# 3                        2024            0/0            0/0    85.60/85.60
# 4                        2023            0/0        8.10/10    93.40/93.40
#
#   Performance_10  Other skills_Aggregate  Degree_value  Stream_value  \
# 0            0/0                0.095238           0.2          0.40
# 1            0/0                0.523810           0.2          0.70
# 2            0/0                0.126984           0.3          0.70
# 3    10.00/10.00                0.285714           0.2         -0.05
# 4    10.00/10.00                0.063492           0.2          0.70
#
#    Availability_value  Current Year Of Graduation_value
# 0                   1                                 0
# 1                   1                                 3
# 2                   1                                 1
# 3                   1                                 3
# 4                   1                                 2

# %%
# Assinging values to performance in studies
Studies_score_10 = []
for item in df['Performance_10']:
    x,y = map(float,item.split('/'))
    #print(x,y)
    try:
        if x <= 10:
            Studies_score_10.append((x/10)*0.05)
        else:
            Studies_score_10.append((x/100)*0.05)
    except:
        Studies_score_10.append(0)
Studies_score_12 = []
for item in df['Performance_12']:
    x,y = map(float,item.split('/'))
    try:
        if x <= 10:
            Studies_score_12.append((x/10)*0.05)
        else:
            Studies_score_12.append((x/100)*0.1)
    except:
        Studies_score_12.append(0)
Studies_score_UG = []
for item in df['Performance_UG']:
    x,y = map(float,item.split('/'))
    try:
        if x <= 10:
            Studies_score_UG.append((x/10)*0.05)
        else:
            Studies_score_UG.append((x/100)*0.05)
    except:
        Studies_score_UG.append(0)
Studies_score_PG = []
for item in df['Performance_PG']:
    x,y = map(float,item.split('/'))
    try:
        if x <= 10:
            Studies_score_PG.append((x/10)*0.1)
        else:
            Studies_score_PG.append((x/100)*0.1)
    except:
        Studies_score_PG.append(0)
studies_score = []
print(len(Studies_score_10))
print(len(Studies_score_12))
print(len(Studies_score_UG))
print(len(Studies_score_PG))
for i in range(len(Studies_score_10)):
    studies_score.append(Studies_score_10[i] + Studies_score_12[i] + Studies_score_UG[i] + Studies_score_PG[i])
df['Studies_value'] = studies_score
df.head(5)
# Out:
# 1136
# 1136
# 1136
# 1136
#    Name  Python (out of 3)  Machine Learning (out of 3)  \
# 0   NaN                  1                            0
# 1   NaN                  2                            0
# 2   NaN                  2                            2
# 3   NaN                  3                            2
# 4   NaN                  2                            2
#
#    Natural Language Processing (NLP) (out of 3)  Deep Learning (out of 3)  \
# 0                                             0                         1
# 1                                             0                         0
# 2                                             0                         0
# 3                                             2                         0
# 4                                             0                         0
#
#                                         Other skills  \
# 0  MS-Excel, MS-Word, Deep Learning, MySQL, Pytho...
# 1  Git, GitHub, Linux, Adobe After Effects, Adobe...
# 2  Amazon Web Services (AWS), Docker, Hadoop, MS-...
# 3  Adobe XD, BIG DATA ANALYTICS, Canva, Data Anal...
# 4  C++ Programming, Data Science, Machine Learnin...
#
#   Are you available for 3 months, starting immediately, for a full-time work from home internship?   \
# 0  Yes, I am available for 3 months starting imme...
# 1  Yes, I am available for 3 months starting imme...
# 2  Yes, I am available for 3 months starting imme...
# 3  Yes, I am available for 3 months starting imme...
# 4  Yes, I am available for 3 months starting imme...
#
#                           Degree                          Stream  \
# 0  Bachelor of Vocation (B.Voc.)            Software Engineering
# 1                         B.Tech  Computer Science & Engineering
# 2       Master of Science (M.S.)      Data Science And Analytics
# 3  Bachelor of Engineering (B.E)                         Unknown
# 4                         B.Tech                Computer Science
#
#    Current Year Of Graduation Performance_PG Performance_UG Performance_12  \
# 0                        2021            0/0         6.50/7            0/0
# 1                        2024            0/0        8.90/10            0/0
# 2                        2022            0/0            0/0            0/0
# 3                        2024            0/0            0/0    85.60/85.60
# 4                        2023            0/0        8.10/10    93.40/93.40
#
#   Performance_10  Other skills_Aggregate  Degree_value  Stream_value  \
# 0            0/0                0.095238           0.2          0.40
# 1            0/0                0.523810           0.2          0.70
# 2            0/0                0.126984           0.3          0.70
# 3    10.00/10.00                0.285714           0.2         -0.05
# 4    10.00/10.00                0.063492           0.2          0.70
#
#    Availability_value  Current Year Of Graduation_value  Studies_value
# 0                   1                                 0         0.0325
# 1                   1                                 3         0.0445
# 2                   1                                 1         0.0000
# 3                   1                                 3         0.1356
# 4                   1                                 2         0.1839

# %%
df.head(5)
# Out:
#    Name  Python (out of 3)  Machine Learning (out of 3)  \
# 0   NaN                  1                            0
# 1   NaN                  2                            0
# 2   NaN                  2                            2
# 3   NaN                  3                            2
# 4   NaN                  2                            2
#
#    Natural Language Processing (NLP) (out of 3)  Deep Learning (out of 3)  \
# 0                                             0                         1
# 1                                             0                         0
# 2                                             0                         0
# 3                                             2                         0
# 4                                             0                         0
#
#                                         Other skills  \
# 0  MS-Excel, MS-Word, Deep Learning, MySQL, Pytho...
# 1  Git, GitHub, Linux, Adobe After Effects, Adobe...
# 2  Amazon Web Services (AWS), Docker, Hadoop, MS-...
# 3  Adobe XD, BIG DATA ANALYTICS, Canva, Data Anal...
# 4  C++ Programming, Data Science, Machine Learnin...
#
#   Are you available for 3 months, starting immediately, for a full-time work from home internship?   \
# 0  Yes, I am available for 3 months starting imme...
# 1  Yes, I am available for 3 months starting imme...
# 2  Yes, I am available for 3 months starting imme...
# 3  Yes, I am available for 3 months starting imme...
# 4  Yes, I am available for 3 months starting imme...
#
#                           Degree                          Stream  \
# 0  Bachelor of Vocation (B.Voc.)            Software Engineering
# 1                         B.Tech  Computer Science & Engineering
# 2       Master of Science (M.S.)      Data Science And Analytics
# 3  Bachelor of Engineering (B.E)                         Unknown
# 4                         B.Tech                Computer Science
#
#    Current Year Of Graduation Performance_PG Performance_UG Performance_12  \
# 0                        2021            0/0         6.50/7            0/0
# 1                        2024            0/0        8.90/10            0/0
# 2                        2022            0/0            0/0            0/0
# 3                        2024            0/0            0/0    85.60/85.60
# 4                        2023            0/0        8.10/10    93.40/93.40
#
#   Performance_10  Other skills_Aggregate  Degree_value  Stream_value  \
# 0            0/0                0.095238           0.2          0.40
# 1            0/0                0.523810           0.2          0.70
# 2            0/0                0.126984           0.3          0.70
# 3    10.00/10.00                0.285714           0.2         -0.05
# 4    10.00/10.00                0.063492           0.2          0.70
#
#    Availability_value  Current Year Of Graduation_value  Studies_value
# 0                   1                                 0         0.0325
# 1                   1                                 3         0.0445
# 2                   1                                 1         0.0000
# 3                   1                                 3         0.1356
# 4                   1                                 2         0.1839

# %%
# Define weights for each feature
# weights are so that aggregate rules are followed
'''
- **Python** (Aggregate: 1.5)
- **Machine Learning** (Aggregate: 1.8)
- **Deep Learning** (Aggregate: 1.8)
- **Natural Language Processing (NLP)** (Aggregate: 1.5)
- **Other Skills Rating** (Aggregate: 0.5)
- **Availability** (Aggregate: 0.5)
- **Degree Rating** (Aggregate: 0.5)
- **Stream Rating** (Aggregate: 1.4)
- **Year of Graduation Rating** (Aggregate: 0.5)
- **Study Rating** (Aggregate: 1)
'''
weights = {
    'Python (out of 3)': 0.5,
    'Machine Learning (out of 3)': 0.6,
    'Natural Language Processing (NLP) (out of 3)': 0.5,
    'Deep Learning (out of 3)': 0.6,
    'Degree_value' : 0.1,
    'Stream_value' : 2,
    'Current Year Of Graduation_value': 0.166,
    'Studies_value' : 2,
    'Availability_value' :0.5
}


cols = []
for item in weights:
    df[item+'_aggregate'] = df[item]*weights[item]
    cols.append(item+'_aggregate')

df['Score'] = df['Other skills_Aggregate']
for item in cols:
    df['Score'] += df[item] 


'''
 Calculate the score for each intern by multiplying the feature values with their respective weights and summing them up
df['Score'] = (df['Python (out of 3)'] * weights['Python (out of 3)'] +
                 df['Machine Learning (out of 3)'] * weights['Machine Learning (out of 3)'] +
                 df['Natural Language Processing (NLP) (out of 3)'] * weights['Natural Language Processing (NLP) (out of 3)'] +
                 df['Deep Learning (out of 3)'] * weights['Deep Learning (out of 3)'] +
                 df['Degree_value'] * weights['Degree_value'] +
                 df['Other skills_value'] * weights['Other skills_value']+
                 df['Are you available for 3 months, starting immediately, for a full-time work from home internship? ']+
                 df['Stream_value']* weights['Stream_value']+
                 df['Current Year Of Graduation_value']* weights['Current Year Of Graudation_value']+
                 df['Studies_Score']* weights['Studies_Score'])

'''
#
# Out:
# "\n Calculate the score for each intern by multiplying the feature values with their respective weights and summing them up\ndf['Score'] = (df['Python (out of 3)'] * weights['Python (out of 3)'] +\n                 df['Machine Learning (out of 3)'] * weights['Machine Learning (out of 3)'] +\n                 df['Natural Language Processing (NLP) (out of 3)'] * weights['Natural Language Processing (NLP) (out of 3)'] +\n                 df['Deep Learning (out of 3)'] * weights['Deep Learning (out of 3)'] +\n                 df['Degree_value'] * weights['Degree_value'] +\n                 df['Other skills_value'] * weights['Other skills_value']+\n                 df['Are you available for 3 months, starting immediately, for a full-time work from home internship? ']+\n                 df['Stream_value']* weights['Stream_value']+\n                 df['Current Year Of Graduation_value']* weights['Current Year Of Graudation_value']+\n                 df['Studies_Score']* weights['Studies_Score'])\n\n"

# %%
df['Score']
# Out:
# 0       2.580238
# 1       4.030810
# 2       4.422984
# 3       5.174914
# 4       4.883292
#           ...
# 1131    4.646984
# 1132    8.851333
# 1133    7.319414
# 1134    4.340492
# 1135    2.129111
# Name: Score, Length: 1136, dtype: float64

# %%
ranked_data = df.sort_values(by='Score', ascending=False)

# Select the top-ranked intern as the best candidate
best_candidate = ranked_data.iloc[0]

print("Best Candidate:")
print(best_candidate)
# Out:
# Best Candidate:
# Name                                                                                                                                               NaN
# Python (out of 3)                                                                                                                                    3
# Machine Learning (out of 3)                                                                                                                          3
# Natural Language Processing (NLP) (out of 3)                                                                                                         3
# Deep Learning (out of 3)                                                                                                                             3
# Other skills                                                                                         C Programming, C++ Programming, Data Analytics...
# Are you available for 3 months, starting immediately, for a full-time work from home internship?     Yes, I am available for 3 months starting imme...
# Degree                                                                                                                                          B.Tech
# Stream                                                                                                                  Computer Science & Engineering
# Current Year Of Graduation                                                                                                                        2024
# Performance_PG                                                                                                                                     0/0
# Performance_UG                                                                                                                                     0/0
# Performance_12                                                                                                                                     0/0
# Performance_10                                                                                                                                     0/0
# Other skills_Aggregate                                                                                                                        0.380952
# Degree_value                                                                                                                                       0.2
# Stream_value                                                                                                                                       0.7
# Availability_value                                                                                                                                   1
# Current Year Of Graduation_value                                                                                                                     3
# Studies_value                                                                                                                                      0.0
# Python (out of 3)_aggregate                                                                                                                        1.5
# Machine Learning (out of 3)_aggregate                                                                                                              1.8
# Natural Language Processing (NLP) (out of 3)_aggregate                                                                                             1.5
# Deep Learning (out of 3)_aggregate                                                                                                                 1.8
# Degree_value_aggregate                                                                                                                            0.02
# Stream_value_aggregate                                                                                                                             1.4
# Current Year Of Graduation_value_aggregate                                                                                                       0.498
# Studies_value_aggregate                                                                                                                            0.0
# Availability_value_aggregate                                                                                                                       0.5
# Score                                                                                                                                         9.398952
# Name: 465, dtype: object

# %%
ranked_data.head(10)
# Out:
#       Name  Python (out of 3)  Machine Learning (out of 3)  \
# 465    NaN                  3                            3
# 862    NaN                  3                            3
# 422    NaN                  3                            3
# 445    NaN                  3                            3
# 182    NaN                  3                            3
# 1000   NaN                  3                            3
# 674    NaN                  3                            3
# 246    NaN                  3                            3
# 36     NaN                  3                            2
# 786    NaN                  3                            3
#
#       Natural Language Processing (NLP) (out of 3)  Deep Learning (out of 3)  \
# 465                                              3                         3
# 862                                              3                         3
# 422                                              3                         3
# 445                                              2                         2
# 182                                              3                         2
# 1000                                             3                         3
# 674                                              2                         3
# 246                                              3                         3
# 36                                               3                         3
# 786                                              3                         3
#
#                                            Other skills  \
# 465   C Programming, C++ Programming, Data Analytics...
# 862   C++ Programming, Computer Vision, Data Analyti...
# 422   Deep Learning, Machine Learning, Natural Langu...
# 445   .NET, Adobe XD, Amazon Web Server (AWS), Artif...
# 182   Machine Learning, MongoDB, Natural Language Pr...
# 1000  Business Analysis, Data Analytics, Data Scienc...
# 674   Data Analytics, Data Science, Deep Learning, J...
# 246   Deep Learning, Flask, Hadoop, JavaScript, Mach...
# 36    Computer Vision, Data Science, Deep Learning, ...
# 786   Computer Vision, Data Analytics, Data Science,...
#
#      Are you available for 3 months, starting immediately, for a full-time work from home internship?   \
# 465   Yes, I am available for 3 months starting imme...
# 862                                No, From 1st august.
# 422   Yes, I am available for 3 months starting imme...
# 445   Yes, I am available for 3 months starting imme...
# 182   Yes, I am available for 3 months starting imme...
# 1000  Yes, I am available for 3 months starting imme...
# 674   Yes, I am available for 3 months starting imme...
# 246   Yes, I am available for 3 months starting imme...
# 36    Yes, I am available for 3 months starting imme...
# 786   Yes, I am available for 3 months starting imme...
#
#                              Degree                                    Stream  \
# 465                          B.Tech            Computer Science & Engineering
# 862                          B.Tech  Artificial Intelligence And Data Science
# 422   Master of Technology (M.Tech)                   Artificial Intelligence
# 445                          B.Tech            Computer Science & Engineering
# 182                  B.Tech (Hons.)                          computer science
# 1000                        Unknown         Data Science And Machine Learning
# 674                          B.Tech                              Data Science
# 246        Master of Science (M.Sc)                                 Economics
# 36                           B.Tech                          computer science
# 786      Bachelor of Science (B.Sc)                          Computer Science
#
#       Current Year Of Graduation  ... Python (out of 3)_aggregate  \
# 465                         2024  ...                         1.5
# 862                         2024  ...                         1.5
# 422                         2023  ...                         1.5
# 445                         2024  ...                         1.5
# 182                         2024  ...                         1.5
# 1000                        2022  ...                         1.5
# 674                         2024  ...                         1.5
# 246                         2023  ...                         1.5
# 36                          2024  ...                         1.5
# 786                         2022  ...                         1.5
#
#      Machine Learning (out of 3)_aggregate  \
# 465                                    1.8
# 862                                    1.8
# 422                                    1.8
# 445                                    1.8
# 182                                    1.8
# 1000                                   1.8
# 674                                    1.8
# 246                                    1.8
# 36                                     1.2
# 786                                    1.8
#
#      Natural Language Processing (NLP) (out of 3)_aggregate  \
# 465                                                 1.5
# 862                                                 1.5
# 422                                                 1.5
# 445                                                 1.0
# 182                                                 1.5
# 1000                                                1.5
# 674                                                 1.0
# 246                                                 1.5
# 36                                                  1.5
# 786                                                 1.5
#
#      Deep Learning (out of 3)_aggregate  Degree_value_aggregate  \
# 465                                 1.8                    0.02
# 862                                 1.8                    0.02
# 422                                 1.8                    0.03
# 445                                 1.2                    0.02
# 182                                 1.2                    0.02
# 1000                                1.8                    0.00
# 674                                 1.8                    0.02
# 246                                 1.8                    0.03
# 36                                  1.8                    0.02
# 786                                 1.8                    0.02
#
#       Stream_value_aggregate  Current Year Of Graduation_value_aggregate  \
# 465                      1.4                                       0.498
# 862                      1.4                                       0.498
# 422                      1.4                                       0.332
# 445                      1.4                                       0.498
# 182                      1.4                                       0.498
# 1000                     1.4                                       0.166
# 674                      1.4                                       0.498
# 246                      0.6                                       0.332
# 36                       1.4                                       0.498
# 786                      1.4                                       0.166
#
#       Studies_value_aggregate  Availability_value_aggregate     Score
# 465                    0.0000                           0.5  9.398952
# 862                    0.3593                           0.0  9.353490
# 422                    0.2454                           0.5  9.329622
# 445                    0.3776                           0.5  9.279727
# 182                    0.2892                           0.5  9.135771
# 1000                   0.2560                           0.5  9.112476
# 674                    0.2656                           0.5  9.005822
# 246                    0.4930                           0.5  8.967698
# 36                     0.1820                           0.5  8.965079
# 786                    0.0750                           0.5  8.935603
#
# [10 rows x 30 columns]
